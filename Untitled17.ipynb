# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayona123/Drug_repurposing/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim
import torch as T
import collections
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from __future__ import print_function
import keras
from keras.models import Sequential

from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
from google.colab import drive
df1 = pd.read_csv('/content/sample_data/Book2.csv',encoding= 'latin-1')
print(df1.to_string())
# Out:
#     Sl. No.                                                   Name of the molecule                                                                                                                                                   smiles  Vina Score  2.39E+00  1.31E+00  -5.65E+00  -3.58E+00  -5.44E+00  -6.31E+00  -1.28E+01  -1.48E+01  -9.46E+00  -1.44E+01  1.56E+01  -7.80E+00  9.76E+00  -7.27E+00  -1.66E+01  -5.30E+00  -1.88E+00  9.12E+00  -4.92E+00  -7.40E+00  -6.19E+00  7.54E+00  -9.51E+00  1.03E+01  4.87E+00  -1.05E+01  -9.88E+00  -6.29E+00   1.15E+00  3.51E-01  -5.74E-01  1.39E+01  2.07E+01  2.03E+00  -1.65E+01  -2.04E+01  1.46E+01  6.36E+00  -8.41E+00  1.76E+01  4.15E+00  -8.05E+00  6.77E+00  1.19E+00  2.67E+00  -9.21E+00  -1.88E+01  8.71E+00  1.76E+01.1  1.32E+01  9.69E+00  6.73E+00  -2.47E+00  1.45E+00  1.14E+00  9.47E+00  -3.69E+00  -9.57E-01  1.05E+01  -6.76E-01  -1.03E+01  1.85E+00  1.09E+01  -2.38E+00  -4.89E+00  -6.97E+00  -4.31E+00  2.56E+01  -5.14E+00  1.35E+01  4.46E-01 
# ...

# %%
def createModel():
    model = Sequential()

    model.add(Flatten(input_shape=(4096,1))
    model.add(Conv2D(16, (3, 3), padding='same', activation='relu', (input_shape=(64,64)))
    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten(input_shape=(256,1)

    
  
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nClasses, activation='softmax'))
    
    return model
# Out:
#   File "<ipython-input-13-ce42a806e7c5>", line 5
#     model.add(Conv2D(16, (3, 3), padding='same', activation='relu', (input_shape=(64,64)))
#         ^
# SyntaxError: invalid syntax
